# %%
import pandas as pd
import numpy as np
import sklearn as skl
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.impute import SimpleImputer

# %%
skl.__version__
# Out:
# '0.20.0'

# %% [markdown]
# ### Getting the data and the features names

# %%
arrhythmia_raw = pd.read_csv('D:/Datasets/arrhythmia/arrhythmia_data.csv')

# %%
features_txt = open('D:/Datasets/arrhythmia/features_raw.txt', 'r').read()

# %%
features = features_txt.split(',')

# %%
arrhythmia_raw.describe()
# Out:
#               age         sex      height      weight  qrs_duration  \
# count  452.000000  452.000000  452.000000  452.000000    452.000000
# mean    46.471239    0.550885  166.188053   68.170354     88.920354
# std     16.466631    0.497955   37.170340   16.590803     15.364394
# min      0.000000    0.000000  105.000000    6.000000     55.000000
# 25%     36.000000    0.000000  160.000000   59.000000     80.000000
# 50%     47.000000    1.000000  164.000000   68.000000     86.000000
# 75%     58.000000    1.000000  170.000000   79.000000     94.000000
# max     83.000000    1.000000  780.000000  176.000000    188.000000
#
#        pr_interval  qt_interval  t_interval  p_interval  vector_qrs  \
# count   452.000000   452.000000  452.000000  452.000000  452.000000
# mean    155.152655   367.207965  169.949115   90.004425   33.676991
# std      44.842283    33.385421   35.633072   25.826643   45.431434
# min       0.000000   232.000000  108.000000    0.000000 -172.000000
# 25%     142.000000   350.000000  148.000000   79.000000    3.750000
# 50%     157.000000   367.000000  162.000000   91.000000   40.000000
# 75%     175.000000   384.000000  179.000000  102.000000   66.000000
# max     524.000000   509.000000  381.000000  205.000000  169.000000
#
#           ...      v6_applitude_q_wave  v6_applitude_r_wave  \
# count     ...               452.000000           452.000000
# mean      ...                -0.278982             9.048009
# std       ...                 0.548876             3.472862
# min       ...                -4.100000             0.000000
# 25%       ...                -0.425000             6.600000
# 50%       ...                 0.000000             8.800000
# 75%       ...                 0.000000            11.200000
# max       ...                 0.000000            23.600000
#
#        v6_applitude_s_wave  v6_applitude_r_sp_wave  v6_applitude_s_sp_wave  \
# count           452.000000              452.000000                   452.0
# mean             -1.457301                0.003982                     0.0
# std               2.002430                0.050118                     0.0
# min             -28.600000                0.000000                     0.0
# 25%              -2.100000                0.000000                     0.0
# 50%              -1.100000                0.000000                     0.0
# 75%               0.000000                0.000000                     0.0
# max               0.000000                0.800000                     0.0
#
#        v6_applitude_p_wave  v6_applitude_t_wave     v6_qrsa    v6_qrsta  \
# count           452.000000           452.000000  452.000000  452.000000
# mean              0.514823             1.222345   19.326106   29.473230
# std               0.347531             1.426052   13.503922   18.493927
# min              -0.800000            -6.000000  -44.200000  -38.600000
# 25%               0.400000             0.500000   11.450000   17.550000
# 50%               0.500000             1.350000   18.100000   27.900000
# 75%               0.700000             2.100000   25.825000   41.125000
# max               2.400000             6.000000   88.800000  115.900000
#
#             class
# count  452.000000
# mean     3.880531
# std      4.407097
# min      1.000000
# 25%      1.000000
# 50%      1.000000
# 75%      6.000000
# max     16.000000
#
# [8 rows x 275 columns]

# %%
arrhythmia_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 452 entries, 0 to 451
# Columns: 280 entries, age to class
# dtypes: float64(120), int64(155), object(5)
# memory usage: 988.8+ KB

# %% [markdown]
# ### Describes of the classes

# %%
classes = arrhythmia_raw['class']

# %%
classes_unique = classes.unique()

# %%
classes_unique = classes_unique.tolist()

# %%
classes_unique
# Out:
# [8, 6, 10, 1, 7, 14, 3, 16, 2, 4, 5, 9, 15]

# %%
dataframes = []

# %%
for _class in classes_unique:
    dataframes.append(arrhythmia_raw.loc[arrhythmia_raw['class'] == _class])

# %%
len(classes_unique)
# Out:
# 13

# %%
len(dataframes)
# Out:
# 13

# %%
describes = {}

# %%
new_dataframes = []

# %%
arrhythmia_data = pd.DataFrame()

# %%
#arrhythmia_data = arrhythmia_data.fillna(0)

# %%
arrhythmia_array = np.array

# %%
imp = SimpleImputer(missing_values=np.NaN, strategy='mean', copy=False)

# %%
for dataframe in dataframes:
    #class_list = dataframe['class'].unique()
    #class_list[0]
    df_array = dataframe.replace('?', np.NaN).values
    #print(class_list[0])
    #describes[class_list[0]] = dataframe.mean()
    imp.fit(df_array)
    imp.transform(df_array)
    new_df = pd.DataFrame(data=df_array, columns=features)
    arrhythmia_data = arrhythmia_data.append(pd.DataFrame(data=df_array, columns=features))
    #new_dataframes.append(new_df)

# %%
test_raw = arrhythmia_raw.loc[arrhythmia_raw['class'] == 2]

# %%
test_raw.head(100)
# Out:
#      age  sex  height  weight  qrs_duration  pr_interval  qt_interval  \
# 28    56    1     164      65            90          164          420
# 29    51    1     160      83            96          147          400
# 66    54    1     160      63            82          158          410
# 77    37    1     171      85            94          148          377
# 82    79    1     150      60            93          178          361
# 86    19    0     165      50            96          151          373
# 108   17    0     170      61            97            0          353
# 157   60    1     160      83            93          121          383
# 179   56    1     162      64            79          172          266
# 184   65    1     155      68            68          200          347
# 186   47    1     163      55            92          187          367
# 187   62    0     170      85           110          157          426
# 192   65    0     180      79            87          137          392
# 193   36    1     172      81            87          145          347
# 200   70    1     160      90            76          187          396
# 212   63    0     174      79            91          151          410
# 213   53    0     169     176           111          166          339
# 216   17    1     156      40            77          106          465
# 235   45    0     173      70           103          155          350
# 237   36    1     149      48            88          170          389
# 245   60    1     155      65            80          144          369
# 256   53    0     165      64            86          153          308
# 259   44    0     170      75            93          163          348
# 275   64    1     156      73            84          163          375
# 277   58    1     150      78            86          147          362
# 294   44    1     160      65            79          170          350
# 295   33    1     160      64           103          145          371
# 296   59    1     160      72            97          149          363
# 304   31    1     160      55            94          124          434
# 308   62    1     170     110            97            0          294
# 322   59    1     161      94            84          152          396
# 323   54    0     164      83           107          182          359
# 329   59    1     155      72            83          209          344
# 351   53    1     156      65            73          160          359
# 357   56    0     170      82            83          183          333
# 359   54    0     160      70            98          169          290
# 360   62    1     157      65            81          174          452
# 366   43    0     165      80           100          188          336
# 367   59    0     160      52            92          128          359
# 368   64    0     170      70            94          162          405
# 372   48    0     182      77            77          196          325
# 375   70    1     160      84            76          165          397
# 411   64    0     160      60            87          131          396
# 449   36    0     166      68           108          176          365
#
#      t_interval  p_interval  vector_qrs  ...   v6_applitude_q_wave  \
# 28          381          99          -8  ...                   0.0
# 29          301          82         -37  ...                   0.0
# 66          141          87          25  ...                   0.0
# 77          142          81          30  ...                   0.0
# 82          132          80          44  ...                   0.0
# 86          147         102          68  ...                  -1.0
# 108         141           0          90  ...                  -1.1
# 157         140          86          94  ...                   0.0
# 179         198          93          -2  ...                   0.0
# 184         164         111         -32  ...                   0.0
# 186         122         102          76  ...                   0.0
# 187         198          94          62  ...                  -1.1
# 192         137          91         -22  ...                   0.0
# 193         207          79          47  ...                  -0.7
# 200         155         121          -1  ...                   0.0
# 212         198          86          16  ...                   0.0
# 213         200         100          86  ...                  -1.0
# 216         147          57          53  ...                  -0.8
# 235         249          75           1  ...                   0.0
# 237         144         106          70  ...                  -1.1
# 245         224          80         -10  ...                   0.0
# 256         214          87           8  ...                  -0.7
# 259         229         104          36  ...                   0.0
# 275         146         104          11  ...                   0.0
# 277         117          79          65  ...                   0.0
# 294         258          91          58  ...                   0.0
# 295         132         102          67  ...                  -1.2
# 296         251          82          -1  ...                   0.0
# 304         127          66          61  ...                  -0.5
# 308         184           0          39  ...                   0.0
# 322         136         100           0  ...                   0.0
# 323         241         127           4  ...                   0.0
# 329         297         105          69  ...                  -0.5
# 351         248          37          33  ...                   0.0
# 357         225          84          53  ...                   0.0
# 359         163          86          49  ...                   0.0
# 360         160         116          53  ...                   0.0
# 366         152          98         -34  ...                   0.0
# 367         245          69          74  ...                  -0.8
# 368         237          95          76  ...                   0.0
# 372         235         104          46  ...                   0.0
# 375         163         108         -10  ...                   0.0
# 411         169          76          -4  ...                   0.0
# 449         194         116         -85  ...                   0.0
#
#     v6_applitude_r_wave v6_applitude_s_wave v6_applitude_r_sp_wave  \
# 28                  5.4                 0.0                    0.0
# 29                  7.3                -3.9                    0.0
# 66                  7.3                -2.1                    0.0
# 77                  7.5                -2.2                    0.0
# 82                  6.7                 0.0                    0.0
# 86                 15.4                -2.1                    0.0
# 108                12.9                 0.0                    0.0
# 157                 9.4                -2.0                    0.0
# 179                 6.8                -1.3                    0.0
# 184                 3.3                -2.5                    0.0
# 186                 6.9                 0.0                    0.0
# 187                 5.9                -2.0                    0.0
# 192                13.9                 0.0                    0.0
# 193                11.2                 0.0                    0.0
# 200                 7.1                -2.9                    0.0
# 212                 4.7                -1.5                    0.0
# 213                12.4                 0.0                    0.0
# 216                12.6                -1.3                    0.0
# 235                10.6                -2.6                    0.0
# 237                 9.3                 0.0                    0.0
# 245                10.2                -4.7                    0.0
# 256                14.3                 0.0                    0.0
# 259                11.0                -1.7                    0.0
# 275                 6.5                 0.0                    0.0
# 277                 9.6                -0.6                    0.0
# 294                 9.9                 0.0                    0.0
# 295                13.4                 0.0                    0.0
# 296                 8.9                 0.0                    0.0
# 304                11.8                -2.8                    0.0
# 308                15.3                 0.0                    0.0
# 322                 9.8                -3.6                    0.0
# 323                13.9                 0.0                    0.0
# 329                 8.8                -1.8                    0.0
# 351                 8.1                 0.0                    0.0
# 357                12.3                 0.0                    0.0
# 359                 6.8                 0.0                    0.0
# 360                11.9                 0.0                    0.0
# 366                 3.1                -4.3                    0.0
# 367                12.5                 0.0                    0.0
# 368                10.3                -3.2                    0.0
# 372                 9.6                -1.7                    0.0
# 375                 8.5                -2.7                    0.0
# 411                 8.2                -1.6                    0.0
# 449                16.3               -28.6                    0.0
#
#     v6_applitude_s_sp_wave  v6_applitude_p_wave  v6_applitude_t_wave  v6_qrsa  \
# 28                     0.0                  0.4                 -1.4     17.2
# 29                     0.0                  0.5                 -1.1      3.6
# 66                     0.0                  0.6                 -0.3     11.0
# 77                     0.0                  0.4                 -0.6     14.7
# 82                     0.0                 -0.2                 -0.9     20.1
# 86                     0.0                  0.3                 -2.2     32.4
# 108                    0.0                 -0.3                 -1.7     29.6
# 157                    0.0                  0.8                  0.5     19.6
# 179                    0.0                  0.3                 -0.6     13.7
# 184                    0.0                  0.7                  0.3      4.1
# 186                    0.0                  0.8                  0.7     17.9
# 187                    0.0                  0.5                  0.5      2.9
# 192                    0.0                  0.8                  0.9     44.4
# 193                    0.0                  0.5                 -0.8     28.4
# 200                    0.0                  0.3                  0.4      7.9
# 212                    0.0                  0.4                 -1.4      7.6
# 213                    0.0                  0.8                  1.5     31.0
# 216                    0.0                  1.0                 -1.7     27.9
# 235                    0.0                  0.9                 -1.4     26.1
# 237                    0.0                  0.6                 -0.9     21.0
# 245                    0.0                  1.0                  0.2     10.2
# 256                    0.0                  0.4                 -3.1     33.5
# 259                    0.0                  1.3                  0.6     27.4
# 275                    0.0                  0.5                  0.4     16.9
# 277                    0.0                  0.5                  0.4     25.8
# 294                    0.0                  0.7                 -1.7     31.6
# 295                    0.0                  0.3                  1.4     38.8
# 296                    0.0                  0.3                 -2.2     30.2
# 304                    0.0                  0.4                 -3.2     16.0
# 308                    0.0                 -0.5                  0.2     36.7
# 322                    0.0                  0.3                 -1.2     15.6
# 323                    0.0                  1.1                 -2.2     47.2
# 329                    0.0                  0.4                 -1.2     14.0
# 351                    0.0                  0.1                 -0.8     22.6
# 357                    0.0                  0.4                 -0.9     41.8
# 359                    0.0                  0.3                 -0.8     24.4
# 360                    0.0                  1.0                 -0.8     35.7
# 366                    0.0                  0.4                 -0.8     -8.8
# 367                    0.0                  0.5                 -1.2     31.6
# 368                    0.0                  1.2                 -1.9     14.3
# 372                    0.0                  0.6                  0.3     20.0
# 375                    0.0                  0.4                  0.2     15.0
# 411                    0.0                  0.3                  1.1     16.4
# 449                    0.0                  1.5                  1.0    -44.2
#
#      v6_qrsta  class
# 28        3.0      2
# 29       -6.3      2
# 66        8.3      2
# 77       10.7      2
# 82       13.1      2
# 86        3.4      2
# 108       9.6      2
# 157      21.8      2
# 179       6.3      2
# 184       8.0      2
# 186      22.3      2
# 187       9.9      2
# 192      47.8      2
# 193      21.2      2
# 200      10.5      2
# 212      -5.0      2
# 213      44.2      2
# 216       8.2      2
# 235       8.5      2
# 237      16.5      2
# 245      12.8      2
# 256      -0.6      2
# 259      33.4      2
# 275      19.5      2
# 277      31.1      2
# 294       6.8      2
# 295      45.5      2
# 296      14.0      2
# 304      -4.4      2
# 308      38.9      2
# 322       7.2      2
# 323      19.5      2
# 329       0.4      2
# 351      10.8      2
# 357      31.8      2
# 359      18.2      2
# 360      28.5      2
# 366     -13.2      2
# 367      18.0      2
# 368      -6.2      2
# 372      23.7      2
# 375      16.2      2
# 411      26.3      2
# 449     -33.2      2
#
# [44 rows x 280 columns]

# %%
test = arrhythmia_data.loc[arrhythmia_data['class'] == 5]

# %%
test.head(100)
# Out:
#    age sex height weight qrs_duration pr_interval qt_interval t_interval  \
# 0   69   1    160     71           75         156         322        172
# 1    1   0    110     10           80         121         287        156
# 2   35   1    160     51           78         147         324        155
# 3   62   1    165     70           72         169         328        135
# 4    1   1    780      6           85         165         237        150
# 5   73   1    160     80           82         136         347        164
# 6   48   0    178     80           91         224         331        159
# 7    0   0    608     10           83         126         232        128
# 8    3   0    105     12           69         155         240        133
# 9   34   1    165     60           74         178         302        127
# 10  15   1    163     38           84         135         340        247
# 11  53   1    156     70           86         141         301        153
# 12   7   1    127     22          185         204         284        123
#
#    p_interval vector_qrs  ...  v6_applitude_q_wave v6_applitude_r_wave  \
# 0         105         18  ...                    0                 6.6
# 1          67        126  ...                 -0.5                 5.1
# 2          75         40  ...                 -0.4                 9.5
# 3          85        -13  ...                    0                 4.2
# 4         106         88  ...                    0                   5
# 5          82         51  ...                 -0.7                 9.5
# 6         122         60  ...                    0                 7.3
# 7          60        125  ...                 -0.7                 4.5
# 8          64         93  ...                    0                 3.3
# 9         117        112  ...                    0                 4.1
# 10         81         32  ...                   -1                14.1
# 11         79         52  ...                 -0.8                10.8
# 12         72       -172  ...                    0                 3.9
#
#    v6_applitude_s_wave v6_applitude_r_sp_wave v6_applitude_s_sp_wave  \
# 0                 -0.8                      0                      0
# 1                 -4.8                      0                      0
# 2                 -2.4                      0                      0
# 3                 -1.2                      0                      0
# 4                 -4.6                      0                      0
# 5                 -2.1                      0                      0
# 6                 -1.2                      0                      0
# 7                 -5.5                      0                      0
# 8                    0                      0                      0
# 9                 -2.9                      0                      0
# 10                -1.8                      0                      0
# 11                   0                      0                      0
# 12                 -15                      0                      0
#
#    v6_applitude_p_wave v6_applitude_t_wave v6_qrsa v6_qrsta class
# 0                  0.2                 1.3    11.8     23.5     5
# 1                  0.8                 0.9    -1.8      5.2     5
# 2                  0.7                 2.4      12     33.1     5
# 3                  0.5                 0.7       6     10.7     5
# 4                  1.3                 0.7     2.7      5.5     5
# 5                  0.7                 0.8    11.8       19     5
# 6                  0.5                 0.4    12.5     14.5     5
# 7                  0.5                 2.5   -11.8      1.7     5
# 8                  1.1                -0.1     5.9      5.4     5
# 9                  1.5                 0.8     1.9      8.1     5
# 10                 0.4                 3.8      24     60.4     5
# 11                 0.5                 1.4      25     36.4     5
# 12                -0.8                 3.6   -36.6    -20.1     5
#
# [13 rows x 280 columns]

# %%
for key, val in describes.items():
    print(key, val)

# %%
arrhythmia_data.info()

# %%
y = arrhythmia_data['class']

# %%
y.unique()

# %%
y.describe()

# %%
X_raw = arrhythmia_data.loc[:, features].values

# %%
X.view()

# %%
X = X.astype(np.float64)

# %%
type(X)

# %%
X = StandardScaler().fit_transform(X)

# %%
X.view()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %% [markdown]
# ### KNN  .95

# %%
pca = PCA(.98)

# %%
knn = KNeighborsClassifier(n_neighbors=1)

# %%
X_train = pca.fit_transform(X_train)

# %%
X_test = pca.transform(X_test)

# %%
pca.explained_variance_ratio_

# %%
knn.fit(X_train, y_train)

# %%
y_pred = knn.predict(X_test)

# %%
accuracy_score(y_test, y_pred)

# %% [markdown]
# ### KNN original dataset

# %%
X_train_od, X_test_od, y_train_od, y_test_od = train_test_split(x, y, test_size=0.2, random_state=0)

# %%
X_train_od.view()

# %%
knn.fit(X_train_od, y_train_od)

# %%
y_pred_od = knn.predict(X_test_od)

# %%
accuracy_score(y_test_od, y_pred_od)
